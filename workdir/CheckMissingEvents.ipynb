# %%
import pandas as pd
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
f15_bar = pd.read_hdf("../files/data/jan2025/mbb_10mm_smear_15bar.h5", "MC/particles")

display(f15_bar)
# Out:
#         event_id  particle_id particle_name  primary  mother_id  initial_x  \
# 0           7250            2            e-        1          0   0.000000
# 1           7250            3         gamma        0          2 -20.501701
# 2           7250           30            e-        0          3 -52.462582
# 3           7250           29            e-        0          3 -52.462582
# 4           7250           28            e-        0          3 -52.462582
# ...          ...          ...           ...      ...        ...        ...
# 442922      3799           12            e-        0          8   1.100006
# 442923      3799           11            e-        0          8   1.100006
# 442924      3799           10            e-        0          8   1.100006
# 442925      3799            9            e-        0          8   1.100006
# 442926      3799            6            e-        0          1  -1.440013
#
# ...

# %%
print(len(f15_bar.event_id.unique()))
# Out:
# 12500
